# %% [markdown]
# ## means

# %%
import numpy

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = numpy.mean(speed)

print(x)
# Out:
# 89.76923076923077

# %% [markdown]
# ## Basic Mean

# %%
import pandas as pd
numbers  = pd.Series([10, 20, 30, 40, 50])
df = numbers.mean()
print(df)
# Out:
# 30.0

# %% [markdown]
# ## Student Marks

# %%
marks = pd.Series([75, 80, 65, 90, 85])
df = marks.mean()
print(df)
# Out:
# 79.0

# %% [markdown]
# ## Ages

# %%
ages = pd.Series([18, 20, 21, 19, 22, 20])
df = ages.mean()
print(df)
# Out:
# 20.0

# %% [markdown]
# ## Monthly Sales

# %%
sales = pd.Series([1200, 1500, 1800, 1300, 2000, 1700])
average_sale = sales.mean()
print(average_sale)
# Out:
# 1583.3333333333333

# %% [markdown]
# ## Temperature

# %%
Temperature = pd.Series([25, 28, 30, 27, 29, 31, 26])
average = Temperature.mean()
print(average)
# Out:
# 28.0

# %% [markdown]
# ## Mean with Labels

# %%
marks  = [80,75,90,85,70]
student = ["Ali", "Ahmed", "Wahid", "Usman", "Hamza"]
df = pd.Series(marks , index= student)
print(df)
average = df.mean()
print(average)
# Out:
# Ali      80
# Ahmed    75
# Wahid    90
# Usman    85
# Hamza    70
# dtype: int64
# 80.0

# %% [markdown]
# ## Mean of a DataFrame Column

# %%
import pandas as pd

data = {
    "Name": ["Ali", "Ahmed", "Wahid", "Usman", "Hamza"],
    "Marks": [80, 75, 90, 85, 70]
}

df = pd.DataFrame(data)

print(df)

average = df["Marks"].mean()

print("Average Marks:", average)
# Out:
#     Name  Marks
# 0    Ali     80
# 1  Ahmed     75
# 2  Wahid     90
# 3  Usman     85
# 4  Hamza     70
# Average Marks: 80.0

# %% [markdown]
# ## Mean of Multiple Columns

# %%
data = {
    'Maths ': [55,66,77,88,99],
    'English' : [11,22,33,44,55],
    'Computer' : [56,67,78,89,90]
}
df = pd.DataFrame(data)
print(df)
Multiple = df.mean()
print(Multiple)
# Out:
#    Maths   English  Computer
# 0      55       11        56
# 1      66       22        67
# 2      77       33        78
# 3      88       44        89
# 4      99       55        90
# Maths       77.0
# English     33.0
# Computer    76.0
# dtype: float64

# %% [markdown]
# ## Mean with Missing Values

# %%
numb = pd.Series([11,22,33,44,55,66])
Missing = numb.isnull()
find = Missing.mean()
print(find)
# Out:
# 0.0

# %% [markdown]
# Real-World Dataset ⭐

# %%
import pandas as pd

df = pd.read_csv("data.csv")

print(df)

age_mean = df["Age"].mean()
salary_mean = df["Salary"].mean()
rating_mean = df["Rating"].mean()

print("Average Age:", age_mean)
print("Average Salary:", salary_mean)
print("Average Rating:", rating_mean)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("data.csv")
#       5 print(df)
#       7 age_mean = df["Age"].mean()
#
# ...

# %% [markdown]
# ## mediun

# %%
import numpy

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = numpy.median(speed)

print(x)
# Out:
# 87.0

# %% [markdown]
# ## Basic Median

# %%
year = [10, 20, 30, 40, 50]
x = numpy.median(year)
print(x)
# Out:
# 30.0

# %% [markdown]
# ## Median with Even Number of Values

# %%
import pandas as pd
numbers = pd.Series([10, 20, 30, 40, 50, 60])
med = numbers.median()
print(med)
# Out:
# 35.0

# %% [markdown]
# ## Unsorted Values

# %%
numbers = pd.Series([50, 10, 40, 20, 30])
med = numbers.median()
print(med)
# Out:
# 30.0

# %% [markdown]
# ## Student Marks

# %%
marks = pd.Series([55, 70, 85, 90, 65, 78, 88])
med = marks.median()
print(med)
# Out:
# 78.0

# %% [markdown]
# ## Ages

# %%
ages = pd.Series([18, 21, 19, 25, 22, 20, 24])
med = ages.median()
print(med)
# Out:
# 21.0

# %% [markdown]
# ## . Median with Labels

# %%
numbers = [80,75,95,65,85]
names = ['hamza' , 'ahmed' , 'wahid' , 'usman' , 'ali']
med = pd.Series(numbers , index = names)
print(med)
x = med.median()
print(x)
# Out:
# hamza    80
# ahmed    75
# wahid    95
# usman    65
# ali      85
# dtype: int64
# 80.0

# %% [markdown]
# ## Median of a DataFrame Column

# %%
numbers = [80,75,95,65,85]
names = ['hamza' , 'ahmed' , 'wahid' , 'usman' , 'ali']
med = pd.DataFrame(numbers , index = names)
print(med)
x = med.median()
print(x)
# Out:
#         0
# hamza  80
# ahmed  75
# wahid  95
# usman  65
# ali    85
# 0    80.0
# dtype: float64

# %% [markdown]
# ## Median of Multiple Columns

# %%
import pandas as pd

data = {
    "Maths": [55, 66, 77, 88, 99],
    "English": [60, 70, 80, 90, 100],
    "Computer": [50, 65, 75, 85, 95]
}

df = pd.DataFrame(data)

print(df)

median = df.median()

print("\nMedian of each subject:")
print(median)
# Out:
#    Maths  English  Computer
# 0     55       60        50
# 1     66       70        65
# 2     77       80        75
# 3     88       90        85
# 4     99      100        95
#
# Median of each subject:
# Maths       77.0
# English     80.0
# Computer    75.0
# dtype: float64

# %% [markdown]
# ## Median by Group

# %%
import pandas as pd

data = {
    "Department": ["IT", "IT", "IT", "HR", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 45000, 50000, 55000]
}

df = pd.DataFrame(data)

print(df)

median_salary = df.groupby("Department")["Salary"].median()

print("\nMedian Salary:")
print(median_salary)
# Out:
#   Department  Salary
# 0         IT   50000
# 1         IT   60000
# 2         IT   70000
# 3         HR   45000
# 4         HR   50000
# 5         HR   55000
#
# Median Salary:
# Department
# HR    50000.0
# IT    60000.0
# Name: Salary, dtype: float64

# %% [markdown]
# ## Basic Mode

# %%
numbers = pd.Series([10, 20, 20, 30, 40])
mod = numbers.mode()
print(mod)
# Out:
# 0    20
# dtype: int64

# %% [markdown]
# ## Repeated Values

# %%
values = pd.Series([5, 5, 10, 15, 15, 15, 20])
mod = values.mode()
print(mod)
# Out:
# 0    15
# dtype: int64

# %% [markdown]
# ## Mode with Strings

# %%
strings = pd.Series(["Apple", "Banana", "Apple", "Orange", "Apple", "Banana"])
mod = strings.mode()
print(mod)
# Out:
# 0    Apple
# dtype: object

# %% [markdown]
# ## Student Marks

# %%
marks = pd.Series([75, 80, 75, 90, 85, 75, 80])
mod = marks.mode()
print(mod)
# Out:
# 0    75
# dtype: int64

# %% [markdown]
# ## Mode with Labels

# %%
numbers = [80,75,95,65,85]
names = ['hamza' , 'ahmed' , 'wahid' , 'usman' , 'ali']
med = pd.Series(numbers , index = names)
print(med)
x = med.mode()
print(x)
# Out:
# hamza    80
# ahmed    75
# wahid    95
# usman    65
# ali      85
# dtype: int64
# 0    65
# 1    75
# 2    80
# 3    85
# 4    95
# dtype: int64

# %% [markdown]
# ## import scipy

# %%
! pip install scipy
# Out:
# ...
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from scipy import stats
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]
x = stats.mode(speed)
print(x)
# Out:
# ModeResult(mode=np.int64(86), count=np.int64(3))

# %% [markdown]
# ## Student Marks

# %%
from scipy import stats

temperature = [25, 28, 25, 30, 27, 25, 29, 28, 25, 31]

x = stats.mode(temperature)

print(x)
# Out:
# ModeResult(mode=np.int64(25), count=np.int64(4))

# %% [markdown]
# ## Temperatures

# %%
from scipy import stats

temperature = [25, 28, 25, 30, 27, 25, 29, 28, 25, 31]

x = stats.mode(temperature)

print(x)
# Out:
# ModeResult(mode=np.int64(25), count=np.int64(4))

# %% [markdown]
# ## Ages

# %%
from scipy import stats

ages = [20, 21, 20, 22, 23, 20, 21, 24, 20, 22]

x = stats.mode(ages)

print(x)
# Out:
# ModeResult(mode=np.int64(20), count=np.int64(4))

# %% [markdown]
# ## Standard deviation

# %%
import numpy

speed = [86,87,88,86,87,85,86]

x = numpy.std(speed)

print(x)
# Out:
# 0.9035079029052513

# %%
speed = [11,22,33,44,55,66,77,88,99]
x = numpy.std(speed)
print(x)
# Out:
# 28.401877872187722

# %% [markdown]
# ## Basic Standard Deviation

# %%
speed = [10, 20, 30, 40, 50]
x = numpy.std(speed)
print(x)
# Out:
# 14.142135623730951

# %% [markdown]
# ## Student Marks

# %%
marks = [65, 70, 75, 80, 85, 90]
x = numpy.std(marks)
print(x)
# Out:
# 8.539125638299666

# %% [markdown]
# ## Calculate Mean and Standard Deviation

# %%
speed = [12, 15, 18, 20, 25, 30]
means = numpy.mean(speed)
standards = numpy.std(speed)
print(means)
print(standards)
# Out:
# 20.0
# 6.027713773341708

# %% [markdown]
# ## Compare Two Datasets

# %%
data1 = [10, 20, 30, 40, 50]
data2 = [25, 27, 29, 31, 33]

one = numpy.std(data1)
two = numpy.std(data2)
print(one)
print(two)
# Out:
# 14.142135623730951
# 2.8284271247461903

# %% [markdown]
# ## Temperature Data

# %%
temperature = [25, 26, 24, 27, 25, 28, 23]

x = numpy.std(temperature)
print(x)
# Out:
# 1.5907898179514348

# %% [markdown]
# ## Using Python Statistics

# %%
import statistics as st

numbers = [10, 12, 15, 18, 20, 25]

x = st.stdev(numbers)

print(x)
# Out:
# 5.501514942874069

# %% [markdown]
# ## Variance

# %%
import numpy

speed = [32,111,138,28,59,77,97]

x = numpy.var(speed)

print(x)
# Out:
# 1432.2448979591834

# %% [markdown]
# ## SD

# %%
import numpy as np

speed = [32,111,138,28,59,77,97]

x = numpy.std(speed)

print(x)
# Out:
# 37.84501153334721

# %% [markdown]
# ## Basic Variance

# %%
speed = np.array([10, 20, 30, 40, 50])
varince = np.var(speed)
print(varince)
# Out:
# 200.0

# %%
speed = np.array([10, 20, 30, 40, 50])
varince = np.std(speed)
print(varince)
# Out:
# 14.142135623730951

# %% [markdown]
# ## Student Marks

# %%
marks = [60, 65, 70, 75, 80, 85]
var = np.var(marks)
print(var)
# Out:
# 72.91666666666667

# %% [markdown]
# ## Mean and Variance

# %%
numbers = [12, 15, 18, 20, 25, 30]
x = np.var(numbers)
y = np.std(numbers)
print(x)
print(y)
# Out:
# 36.333333333333336
# 6.027713773341708

# %% [markdown]
# ## Compare Two Datasets

# %%
data1 = [10, 20, 30, 40, 50]
data2 = [24, 26, 28, 30, 32]
x = np.var(data1)
y = np.var(data2)
print(x)
print(y)
# Out:
# 200.0
# 8.0

# %% [markdown]
# ## Temperature Variance

# %%
temperature = [25, 26, 24, 27, 25, 28, 23]
x = np.var(temperature)
print(x)
# Out:
# 2.5306122448979593

# %% [markdown]
# ## Using Python statistics

# %%
import statistics as st

numbers = [10, 12, 15, 18, 20, 25]

x = st.variance(numbers)

print(x)
# Out:
# 30.266666666666666

# %% [markdown]
# # Percentile

# %%
import numpy

ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]

x = numpy.percentile(ages, 75)

print(x)
# Out:
# 43.0

# %% [markdown]
# ## Basic Percentile

# %%
ages = np.array( [5, 10, 15, 20, 25, 30, 35, 40, 45])
x = np.percentile(ages , 50)
print(x)
# Out:
# 25.0

# %% [markdown]
# ## Student Marks

# %%
marks = np.array([10, 20, 30, 40, 50, 60, 70, 80])
x = np.percentile(marks , 50)
print(x)
# Out:
# 45.0

# %% [markdown]
# ## Find the 25th Percentile

# %%
TwenthFive = np.array([45, 55, 60, 65, 70, 75, 80, 85, 90])
x = np.percentile(TwenthFive , 25)
print(x)
# Out:
# 60.0

# %% [markdown]
# ## Find Multiple Percentiles

# %%
import numpy as np

data = np.array([12, 15, 18, 20, 25, 30, 35, 40, 50, 60])

x = np.percentile(data, [25, 50, 75])

print(x)
# Out:
# [18.5  27.5  38.75]

# %% [markdown]
# ## Employee Salaries

# %%
salaries = np.array([25000, 30000, 35000, 40000, 45000, 50000, 60000, 75000])
x = np.percentile(salaries , 90)
print(x)
# Out:
# 64500.0

# %% [markdown]
# ## Temperature Data

# %%
temperature = np.array([20, 22, 25, 27, 30, 31, 33, 35, 38, 40])
x = np.percentile(temperature , 75)
print(x)
# Out:
# 34.5

# %% [markdown]
# ## Compare Percentiles

# %%
data = np.array([5, 10, 15, 20, 25, 30, 35, 40, 45, 50])
x = np.percentile(data, [25,50,75])
print(x)
# Out:
# [16.25 27.5  38.75]

# %% [markdown]
# ## Real-World Age Dataset ⭐

# %%
age = np.array([5, 31, 43, 48, 50, 41, 7, 11, 15, 39,
        80, 82, 32, 2, 8, 6, 25, 36, 27, 61, 31])

x = np.percentile(age , [20,50,75])
print(x)
# Out:
# [ 8. 31. 43.]

# %% [markdown]
# ## Complete Percentile Analysis.

# %%
import numpy as np

marks = np.array([
    45, 50, 55, 60, 65,
    70, 72, 75, 80, 85,
    88, 90, 95, 98, 100
])

p10 = np.percentile(marks, 10)
p25 = np.percentile(marks, 25)
p50 = np.percentile(marks, 50)
p75 = np.percentile(marks, 75)
p90 = np.percentile(marks, 90)

print("10th percentile:", p10)
print("25th percentile:", p25)
print("50th percentile:", p50)
print("75th percentile:", p75)
print("90th percentile:", p90)
# Out:
# 10th percentile: 52.0
# 25th percentile: 62.5
# 50th percentile: 75.0
# 75th percentile: 89.0
# 90th percentile: 96.8

# %% [markdown]
# # Data Distribution

# %%
import numpy

x = numpy.random.uniform(0.0, 5.0, 250)

print(x)
# Out:
# [4.29327756e+00 2.49832671e+00 3.88456878e+00 1.55868171e+00
#  3.81460639e+00 6.64576395e-01 4.24601533e+00 1.73329039e+00
#  4.36611642e+00 2.92482429e+00 3.90733945e+00 2.49028677e+00
#  3.77215087e-01 4.93901510e+00 1.09727806e+00 4.26744883e+00
#  3.38779026e+00 2.98527127e+00 3.21448272e+00 4.49291175e+00
#  3.37847420e+00 3.69868666e+00 4.42355571e+00 1.61365693e+00
#  2.28994710e+00 4.99512008e+00 1.16005546e+00 1.25285038e+00
#  2.70826727e+00 2.91518753e+00 4.77604421e+00 2.07364716e-01
#  3.01898642e+00 1.19023916e+00 3.63387679e+00 2.65977906e+00
#  1.01076644e+00 3.28871433e+00 5.15392465e-01 4.58297281e+00
#  3.24668659e+00 4.66825957e-01 4.51844465e+00 3.13049123e-01
#  1.21842888e+00 4.15022305e+00 2.60188197e+00 1.93034734e+00
#  3.08536021e+00 3.78382289e+00 4.89971996e+00 4.36743528e+00
#  3.85250033e+00 9.02691069e-01 3.74241163e+00 3.27993988e+00
#  1.50115569e+00 2.70725397e+00 1.50413453e+00 4.06671593e+00
# ...

# %%
import numpy as np
x = np.random.uniform(0.0 , 5.0 , 250)
print(x)
# Out:
# [2.1415934  2.31546027 3.26215053 0.90470162 0.14301638 2.55027034
#  1.5601899  1.1139009  4.81323837 1.49804539 0.16308491 1.13161822
#  1.82570277 0.30981724 0.15083544 2.51505538 1.0281248  2.77720026
#  0.7819761  1.74416849 3.93316042 1.86697354 1.16770781 4.21882673
#  3.734941   2.70685797 4.79429765 1.37190291 2.64476113 3.31570116
#  3.81091884 2.74844202 0.69727738 3.53327598 1.15923321 3.54274093
#  2.03651722 3.70111472 0.66424215 4.99660997 3.95109943 0.35394567
#  0.24325299 3.95310139 1.62541238 3.57272172 1.91818654 0.05590269
#  0.3296071  1.17980824 1.02591473 0.00596828 4.50410275 3.86641026
#  4.09174753 4.61006311 2.97227158 3.7642506  0.67782153 2.23974856
#  0.78187519 4.63811198 4.96134554 1.82172532 1.43600351 0.10618254
#  3.33046179 1.28514454 1.70533235 2.98122504 4.58395535 4.78774868
#  0.92976644 1.12059893 4.45590302 1.5611885  4.94161374 4.52591357
#  1.66363935 3.69591655 3.93943016 1.16683018 4.99486974 3.1412492
# ...

# %% [markdown]
# ## Basic Data Distribution

# %%
data = np.array([10, 20, 20, 30, 40, 40, 40, 50, 60])
means = np.mean(data)
medians = np.median(data)
minimums = np.min(data)
maximums = np.max(data)
print(means)
print(medians)
print(minimums)
print(maximums)
# Out:
# 34.44444444444444
# 40.0
# 10
# 60

# %% [markdown]
# ## Generate Random Data

# %%
x = np.random.randint(1,50,100)
print(x)
# Out:
# [49 44 33 25 11 29  5 45 44 39  5 22 12 24 29 46 34 22 49 15 16 13 27  8
#  15  5 44 14 45 33  5 47 43  3 19 41 19 12 38 31  1 27 39 31  2 33 28  1
#  21 39 18 16 25  5 10 11 48 41 38 45 23 37  2 38 14  2 27  1 42  4  2  6
#  18 31 42 10 27 36 44  7 32 44 22 21  3 45 13  7 47 17 23 24 49 18 24 48
#  43 26 20 44]

# %% [markdown]
# ## Generate Random Floating-Point Data

# %%
x = np.random.uniform(0 , 1 , 50)
print(x)
# Out:
# [0.3342086  0.41371189 0.66483916 0.46154872 0.2474755  0.7063909
#  0.03165769 0.19389362 0.78890906 0.14349484 0.90893104 0.58147059
#  0.79996917 0.0218184  0.34777672 0.87499343 0.33996498 0.43696902
#  0.6482075  0.81632595 0.35347636 0.04153933 0.33595307 0.63475813
#  0.03231167 0.85166817 0.67638957 0.97317768 0.9661661  0.27026399
#  0.49130478 0.13303308 0.1004789  0.79272046 0.71821845 0.49108196
#  0.55667236 0.09018679 0.88577445 0.37832135 0.8208686  0.15201866
#  0.91882676 0.92761995 0.97401008 0.72078151 0.48194832 0.47409884
#  0.47709699 0.07019769]

# %% [markdown]
# ## Create a Normal Distribution

# %%
import numpy as np

data = np.random.normal(50, 10, 1000)

print(data[:10])
# Out:
# [49.16588778 48.83348748 44.46115067 67.83961997 41.18133307 50.23766055
#  63.42770588 34.95556651 57.47151457 57.98377223]

# %% [markdown]
# ## Plot a Distribution 📈

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(50, 10, 1000)
plt.hist(data)

plt.show()
print(data[:10])
# Out:
# [56.75607788 45.7080736  70.16534112 72.08801748 62.39498341 52.09539853
#  51.27041401 46.63726164 52.69023465 57.05115067]

# %% [markdown]
# ## Compare Two Distributions

# %%
data1 = np.random.normal(50, 5, 1000)
data2 = np.random.normal(50, 15, 1000)
plt.hist(data1)
plt.hist(data2)
plt.show(data1)
plt.show(data2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 5
#       3 plt.hist(data1)
#       4 plt.hist(data2)
# ----> 5 plt.show(data1)
#       6 plt.show(data2)
#
# File c:\Users\wahid\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:613, in show(*args, **kwargs)
#     569 """
#     570 Display all open figures.
#     571
#    (...)
#     610 explicitly there.
#     611 """
#     612 _warn_if_gui_out_of_main_thread()
# --> 613 return _get_backend_mod().show(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib_inline\backend_inline.py:98, in show(close, block)
#      95 show._to_draw = []
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
# ---> 98 if close and Gcf.get_all_fig_managers():
#      99     matplotlib.pyplot.close("all")
#
# ...

# %% [markdown]
# ## Uniform Distribution

# %%
x = np.random.uniform(1,100,1000)
plt.hist(x)
plt.show()

# %% [markdown]
# ## ⭐ Complete Data Distribution Project

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
data = np.random.normal(100, 20, 1000)

# First 10 values
print("First 10 values:")
print(data[:10])

# Mean
mean = np.mean(data)
print("Mean:", mean)

# Median
median = np.median(data)
print("Median:", median)

# Variance
variance = np.var(data)
print("Variance:", variance)

# Standard deviation
std = np.std(data)
print("Standard Deviation:", std)

# Percentiles
p25 = np.percentile(data, 25)
p50 = np.percentile(data, 50)
p75 = np.percentile(data, 75)

print("25th Percentile:", p25)
print("50th Percentile:", p50)
print("75th Percentile:", p75)

# Minimum and Maximum
print("Minimum:", np.min(data))
print("Maximum:", np.max(data))

# Histogram
plt.hist(data, bins=20)

plt.title("Data Distribution")
plt.xlabel("Values")
plt.ylabel("Frequency")

plt.show()
# Out:
# First 10 values:
# [130.84996005  74.98492516 133.83607278 108.04349254 106.4048399
#   88.34030256  70.67068291 123.25078042 126.90323192  99.91005698]
# Mean: 100.28658552524007
# Median: 100.90089267636674
# Variance: 424.59870592438364
# Standard Deviation: 20.605793018575714
# 25th Percentile: 86.60257612453938
# 50th Percentile: 100.90089267636674
# 75th Percentile: 114.10490240498174
# Minimum: 25.837853050152106
# Maximum: 159.92094829689108

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.uniform(0.0, 5.0, 250)

plt.hist(x, 5)
plt.show()

# %% [markdown]
# ## Normal distribution

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 100000)

plt.hist(x, 100)
plt.show()

# %% [markdown]
# ## Generate Normal Distribution

# %%
x = np.random.normal(50 , 10 , 100)
print(x[:10])
# Out:
# [58.93636495 53.16027417 37.62363265 57.24138818 34.15999059 58.32447307
#  43.47577783 58.84230075 46.74108753 53.02257384]

# %% [markdown]
# ## Generate 500 Values

# %%
x = np.random.normal(100 , 15 , 500)
means = np.mean(x)
sd = np.std(x)
print(means)
print(sd)
print(x[:5])
# Out:
# 100.12451088077009
# 15.364432142241558
# [105.30224656  89.01617929  82.99913435  94.39372076 116.29922668]

# %% [markdown]
# ## Plot Normal Distribution 📈

# %%
data = np.random.normal(50, 10, 1000)
title = plt.title("Normal distribution")
xlabels = plt.xlabel("Digits")
ylabels = plt.ylabel("Frequency")
plt.hist(data)
plt.show()

# %% [markdown]
# ## Compare Two Normal Distributions

# %%
data1 = np.random.normal(50, 5, 1000)
data2 = np.random.normal(50, 15, 1000)
plt.hist(data1)
plt.hist(data2)
plt.show()

# %% [markdown]
# ## Normal Distribution Percentiles

# %%
data = np.random.normal(100, 20, 1000)
first = np.percentile(data , 25)
twoth = np.percentile(data , 50)
third = np.percentile(data , 75)
fourth = np.percentile(data , 90)
print(first)
print(twoth)
print(third)
print(fourth)
# Out:
# 85.99064172586606
# 100.52185497598816
# 112.77851151828182
# 124.8141882755876

# %% [markdown]
# ## Different Means

# %%
import numpy as np
import matplotlib.pyplot as plt

data1 = np.random.normal(30, 5, 500)
data2 = np.random.normal(50, 5, 500)
data3 = np.random.normal(70, 5, 500)

plt.hist(data1, bins=20, alpha=0.5)
plt.hist(data2, bins=20, alpha=0.5)
plt.hist(data3, bins=20, alpha=0.5)

plt.title("Normal Distributions with Different Means")
plt.xlabel("Values")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ## scatter plot

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
x = [1,2,3,4,5,6,7,8]
y = [11,22,33,44,55,66,77,88]
plt.scatter(x , y)
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 1000)
y = numpy.random.normal(10.0, 2.0, 1000)

plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## Basic Scatter Plot

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.scatter(x , y)
plt.show()

# %% [markdown]
# ## Student Study Hours vs Marks

# %%
hours = [1, 2, 3, 4, 5, 6, 7, 8]
marks = [40, 45, 50, 55, 65, 70, 80, 90]
plt.title("Student Study Hours vs Marks")
plt.xlabel("HOurs")
plt.ylabel("Marks")
plt.scatter(hours , marks)
plt.show()

# %% [markdown]
# ## Age vs Height

# %%
age = [10, 12, 14, 16, 18, 20, 22]
height = [130, 140, 150, 160, 168, 172, 175]
plt.scatter(age , height)
plt.show()

# %% [markdown]
# ## Temperature vs Ice Cream Sales

# %%
temperature = [20, 22, 25, 27, 30, 32, 35, 38]
sales = [100, 120, 150, 170, 210, 240, 280, 320]
plt.scatter(temperature , sales)
plt.show()
